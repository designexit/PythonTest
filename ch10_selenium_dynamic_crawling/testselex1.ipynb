# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
driver = webdriver.Chrome()
driver.get('https://google.com')
# r = driver.execute_script('return 100*50')
# print(r)
driver.get("https://www.youtube.com/c/paikscuisine/videos")
all_videos = driver.find_elements(By.ID, "dismissible")
print(all_videos)

time.sleep(2)
datas = []
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="1ecbc9c21c4cdc5b9de7fca7fb469596", element="2B17B4412CFDA08D6B945E6E49BBB2E9_element_18")>, <selenium.webdriver.remote.webelement.WebElement (session="1ecbc9c21c4cdc5b9de7fca7fb469596", element="2B17B4412CFDA08D6B945E6E49BBB2E9_element_25")>, <selenium.webdriver.remote.webelement.WebElement (session="1ecbc9c21c4cdc5b9de7fca7fb469596", element="2B17B4412CFDA08D6B945E6E49BBB2E9_element_32")>, <selenium.webdriver.remote.webelement.WebElement (session="1ecbc9c21c4cdc5b9de7fca7fb469596", element="2B17B4412CFDA08D6B945E6E49BBB2E9_element_52")>, <selenium.webdriver.remote.webelement.WebElement (session="1ecbc9c21c4cdc5b9de7fca7fb469596", element="2B17B4412CFDA08D6B945E6E49BBB2E9_element_53")>, <selenium.webdriver.remote.webelement.WebElement (session="1ecbc9c21c4cdc5b9de7fca7fb469596", element="2B17B4412CFDA08D6B945E6E49BBB2E9_element_54")>, <selenium.webdriver.remote.webelement.WebElement (session="1ecbc9c21c4cdc5b9de7fca7fb469596", element="2B17B4412CFDA08D6B945E6E49BBB2E9_element_55")>, <selenium.webdriver.remote.webelement.WebElement (session="1ecbc9c21c4cdc5b9de7fca7fb469596", element="2B17B4412CFDA08D6B945E6E49BBB2E9_element_56")>, <selenium.webdriver.remote.webelement.WebElement (session="1ecbc9c21c4cdc5b9de7fca7fb469596", element="2B17B4412CFDA08D6B945E6E49BBB2E9_element_57")>, <selenium.webdriver.remote.webelement.WebElement (session="1ecbc9c21c4cdc5b9de7fca7fb469596", element="2B17B4412CFDA08D6B945E6E49BBB2E9_element_58")>, <selenium.webdriver.remote.webelement.WebElement (session="1ecbc9c21c4cdc5b9de7fca7fb469596", element="2B17B4412CFDA08D6B945E6E49BBB2E9_element_59")>, <selenium.webdriver.remote.webelement.WebElement (session="1ecbc9c21c4cdc5b9de7fca7fb469596", element="2B17B4412CFDA08D6B945E6E49BBB2E9_element_60")>, <selenium.webdriver.remote.webelement.WebElement (session="1ecbc9c21c4cdc5b9de7fca7fb469596", element="2B17B4412CFDA08D6B945E6E49BBB2E9_element_61")>, <selenium.webdriver.remote.webelement.WebElement (session="1ecbc9c21c4cdc5b9de7fca7fb469596", element="2B17B4412CFDA08D6B945E6E49BBB2E9_element_62")>, <selenium.webdriver.remote.webelement.WebElement (session="1ecbc9c21c4cdc5b9de7fca7fb469596", element="2B17B4412CFDA08D6B945E6E49BBB2E9_element_63")>, <selenium.webdriver.remote.webelement.WebElement (session="1ecbc9c21c4cdc5b9de7fca7fb469596", element="2B17B4412CFDA08D6B945E6E49BBB2E9_element_64")>, <selenium.webdriver.remote.webelement.WebElement (session="1ecbc9c21c4cdc5b9de7fca7fb469596", element="2B17B4412CFDA08D6B945E6E49BBB2E9_element_65")>, <selenium.webdriver.remote.webelement.WebElement (session="1ecbc9c21c4cdc5b9de7fca7fb469596", element="2B17B4412CFDA08D6B945E6E49BBB2E9_element_66")>, <selenium.webdriver.remote.webelement.WebElement (session="1ecbc9c21c4cdc5b9de7fca7fb469596", element="2B17B4412CFDA08D6B945E6E49BBB2E9_element_67")>, <selenium.webdriver.remote.webelement.WebElement (session="1ecbc9c21c4cdc5b9de7fca7fb469596", element="2B17B4412CFDA08D6B945E6E49BBB2E9_element_68")>, <selenium.webdriver.remote.webelement.WebElement (session="1ecbc9c21c4cdc5b9de7fca7fb469596", element="2B17B4412CFDA08D6B945E6E49BBB2E9_element_69")>, <selenium.webdriver.remote.webelement.WebElement (session="1ecbc9c21c4cdc5b9de7fca7fb469596", element="2B17B4412CFDA08D6B945E6E49BBB2E9_element_70")>, <selenium.webdriver.remote.webelement.WebElement (session="1ecbc9c21c4cdc5b9de7fca7fb469596", element="2B17B4412CFDA08D6B945E6E49BBB2E9_element_71")>, <selenium.webdriver.remote.webelement.WebElement (session="1ecbc9c21c4cdc5b9de7fca7fb469596", element="2B17B4412CFDA08D6B945E6E49BBB2E9_element_72")>, <selenium.webdriver.remote.webelement.WebElement (session="1ecbc9c21c4cdc5b9de7fca7fb469596", element="2B17B4412CFDA08D6B945E6E49BBB2E9_element_73")>, <selenium.webdriver.remote.webelement.WebElement (session="1ecbc9c21c4cdc5b9de7fca7fb469596", element="2B17B4412CFDA08D6B945E6E49BBB2E9_element_74")>, <selenium.webdriver.remote.webelement.WebElement (session="1ecbc9c21c4cdc ...

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
import urllib.request

# chrome_options = webdriver.ChromeOptions()
# chrome_options.binary = 'C://chromedriver_win32/chromedriver.exe' # 드라이버 실행파일 경로
query = '춘식이'
driver = webdriver.Chrome()
driver.get(f'https://www.google.com/imghp')
# 구글 이미지 검색창 이름이 : q
search_bar = driver.find_element(By.NAME,"q")
# 검색 키워드를 춘식이 설정
search_bar.send_keys(query)
# 전달. 
search_bar.submit()
# 잠시 대기 시간 ms 1000ms = 1초 
PAUSE_TIME = 10
# 현재 문서의 스크롤의 높이를 표시. 
last_hegiht = driver.execute_script("return window.scrollY")
print(f"처음 last_hegiht : {last_hegiht}")
new_height = 0

interval = 2
prev_height = driver.execute_script("return document.body.scrollHeight")

    #  결과 더보기 버튼 .LZ4I
    #     resultMoreBtn = driver.find_element(By.CSS_SELECTOR,".LZ4I")
    #     resultMoreBtn.click()
    #     continue

while True:
    #화면 가장 아래로 스크롤 내리기
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight)")
    time.sleep(interval)

    curr_height = driver.execute_script("return document.body.scrollHeight")
    if curr_height == prev_height:
        break
    
    prev_height = curr_height


# while True :
#     # 스크롤 50px 아래로 이동 수행. 
#     driver.execute_script("window.scrollTo(0,500)")
#     last_hegiht2 = driver.execute_script("return document.body.scrollHeight")
#     print(f"스크롤 이동 명령후 길이 조회 : {last_hegiht2}")
#     # 2 ms 대기
#     time.sleep(PAUSE_TIME)
#     # 이동 후,  스크롤 높이 
#     new_height = driver.execute_script("return document.body.scrollHeight")
#     print(f"반복 new_height : {new_height}")
#     # 스크롤 이동 후 높이가, 크다면 이동했다면
#     if new_height - last_hegiht > 0 :
#         # 지난 높이에 대입.
#         last_hegiht = new_height
#         # 다시 반복문으로 돌아가 다시, 50px 내림 
 
#         continue
#     # elif new_height - last_hegiht == 0 :
#     #     # 결과 더보기 버튼 .LZ4I
#     #     resultMoreBtn = driver.find_element(By.CSS_SELECTOR,".LZ4I")
#     #     resultMoreBtn.click()
#     #     continue
#     else :
#         break
#     # 해당 스크롤을 다 내린후, 해당 이미지의 CSS_SELECTOR 를 이용해, 해당 클래스 모두를
#     # 추출해서 리스트에 담음
img_elements = driver.find_elements(By.CSS_SELECTOR,".rg_i")
# 다시 이미지만 추출해서 담음 임시 리스트 
imgs = []
# enumerate 함수 이용하면 해당 인덱스도 같이 추출 가능. 
for idx, img in enumerate(img_elements) :
    print(f"{query} : {idx+1}/{len(img_elements)} proceed...")
    try :
        # 이미지 클릭
        img.click()
        # 잠시 대기 
        time.sleep(PAUSE_TIME)
        # 이부분에서 에러나면, 직접 개발자 도구 활용해서 XPATH 추출한 뒤에 변경
        
        img_src = img.get_attribute('src')
        img_alt = img.get_attribute('alt')
        imgs.append({
            'alt' : img_alt,
            'src' : img_src
        })
        
    except :
        print(f'err in {idx}')
        pass
driver.close()
save_path = f'C:\ccestcrawl\{query}'
import os
if not os.path.exists(save_path):
    os.mkdir(save_path)
total_N = len(imgs)
for idx, one in enumerate(imgs):
    src = one['src']
    alt = one['alt']
    urllib.request.urlretrieve(src,  f"{save_path}\{query}_{idx}.png")
    print(idx, alt)
print('done')
# Out:
# <string>:94: SyntaxWarning: invalid escape sequence '\{'
# <string>:102: SyntaxWarning: invalid escape sequence '\{'
# <>:94: SyntaxWarning: invalid escape sequence '\{'
# <>:94: SyntaxWarning: invalid escape sequence '\c'
# <>:102: SyntaxWarning: invalid escape sequence '\{'
# <string>:94: SyntaxWarning: invalid escape sequence '\{'
# <string>:102: SyntaxWarning: invalid escape sequence '\{'
# <>:94: SyntaxWarning: invalid escape sequence '\{'
# <>:94: SyntaxWarning: invalid escape sequence '\c'
# <>:102: SyntaxWarning: invalid escape sequence '\{'
# /var/folders/w8/dhsjkhfn205_vq9r6d5nxq1w0000gn/T/ipykernel_1946/2071511420.py:94: SyntaxWarning: invalid escape sequence '\{'
#   save_path = f'C:\ccestcrawl\{query}'
# /var/folders/w8/dhsjkhfn205_vq9r6d5nxq1w0000gn/T/ipykernel_1946/2071511420.py:94: SyntaxWarning: invalid escape sequence '\c'
#   save_path = f'C:\ccestcrawl\{query}'
# /var/folders/w8/dhsjkhfn205_vq9r6d5nxq1w0000gn/T/ipykernel_1946/2071511420.py:102: SyntaxWarning: invalid escape sequence '\{'
#   urllib.request.urlretrieve(src,  f"{save_path}\{query}_{idx}.png")
# 처음 last_hegiht : 0
# 춘식이 : 1/397 proceed...
# err in 0
# 춘식이 : 2/397 proceed...
# err in 1
# 춘식이 : 3/397 proceed...
# err in 2
# 춘식이 : 4/397 proceed...
# err in 3
# 춘식이 : 5/397 proceed...
# err in 4
# 춘식이 : 6/397 proceed...
# err in 5
# 춘식이 : 7/397 proceed...
# err in 6
# 춘식이 : 8/397 proceed...
# err in 7
# 춘식이 : 9/397 proceed...
# err in 8
# 춘식이 : 10/397 proceed...
# err in 9
# 춘식이 : 11/397 proceed...
# err in 10
# 춘식이 : 12/397 proceed...
# err in 11
# 춘식이 : 13/397 proceed...
# err in 12
# 춘식이 : 14/397 proceed...
# err in 13
# 춘식이 : 15/397 proceed...
# err in 14
# 춘식이 : 16/397 proceed...
# err in 15
# 춘식이 : 17/397 proceed...
# err in 16
# 춘식이 : 18/397 proceed...
# err in 17
# 춘식이 : 19/397 proceed...
# err in 18
# 춘식이 : 20/397 proceed...
# err in 19
# 춘식이 : 21/397 proceed...
# err in 20
# 춘식이 : 22/397 proceed...
# err in 21
# 춘식이 : 23/397 proceed...
# err in 22
# 춘식이 : 24/397 proceed...
# err in 23
# 춘식이 : 25/397 proceed...
# err in 24
# 춘식이 : 26/397 proceed...
# err in 25
# 춘식이 : 27/397 proceed...
# err in 26
# 춘식이 : 28/397 proceed...
# err in 27
# 춘식이 : 29/397 proceed...
# err in 28
# 춘식이 : 30/397 proceed...
# err in 29
# 춘식이 : 31/397 proceed...
# err in 30
# 춘식이 : 32/397 proceed...
# err in 31
# 춘식이 : 33/397 proceed...
# err in 32
# 춘식이 : 34/397 proceed...
# err in 33
# 춘식이 : 35/397 proceed...
# err in 34
# 춘식이 : 36/397 proceed...
# err in 35
# 춘식이 : 37/397 proceed...
# err in 36
# 춘식이 : 38/397 proceed...
# err in 37
# 춘식이 : 39/397 proceed...
# err in 38
# 춘식이 : 40/397 proceed...
# err in 39
# 춘식이 : 41/397 proceed...
# err in 40
# 춘식이 : 42/397 proceed...
# err in 41
# 춘식이 : 43/397 proceed...
# err in 42
# 춘식이 : 44/397 proceed...
# err in 43
# 춘식이 : 45/397 proceed...
# err in 44
# 춘식이 : 46/397 proceed...
# err in 45
# 춘식이 : 47/397 proceed...
# err in 46
# 춘식이 : 48/397 proceed...
# err in 47
# 춘식이 : 49/397 proceed...
# err in 48
# 춘식이 : 50/397 proceed...
# err in 49
# 춘식이 : 51/397 proceed...
# err in 50
# 춘식이 : 52/397 proceed...
# err in 51
# 춘식이 : 53/397 proceed...
# err in 52
# 춘식이 : 54/397 proceed...
# err in 53
# 춘식이 : 55/397 proceed...
# err in 54
# 춘식이 : 56/397 proceed...
# err in 55
# 춘식이 : 57/397 proceed...
# err in 56
# 춘식이 : 58/397 proceed...
# err in 57
# 춘식이 : 59/397 proceed...
# err in 58
# 춘식이 : 60/397 proceed...
# err in 59
# 춘식이 : 61/397 proceed...
# err in 60
# 춘식이 : 62/397 proceed...
# err in 61
# 춘식이 : 63/397 proceed...
# err in 62
# 춘식이 : 64/397 proceed...
# err in 63
# 춘식이 : 65/397 proceed...
# err in 64
# 춘식이 : 66/397 proceed...
# err in 65
# 춘식이 : 67/397 proceed...
# err in 66
# 춘식이 : 68/397 proceed...
# err in 67
# 춘식이 : 69/397 proceed...
# err in 68
# 춘식이 : 70/397 proceed...
# err in 69
# 춘식이 : 71/397 proceed...
# err in 70
# 춘식이 : 72/397 proceed...
# err in 71
# 춘식이 : 73/397 proceed...
# err in 72
# 춘식이 : 74/397 proceed...
# err in 73
# 춘식이 : 75/397 proceed...
# err in 74
# 춘식이 : 76/397 proceed...
# err in 75
# 춘식이 : 77/397 proceed...
# err in 76
# 춘식이 : 78/397 proceed...
# err in 77
# 춘식이 : 79/397 proceed...
# err in 78
# 춘식이 : 80/397 proceed...
# err in 79
# 춘식이 : 81/397 proceed...
# err in 80
# 춘식이 : 82/397 proceed...
# err in 81
# 춘식이 : 83/397 proceed...
# err in 82
# 춘식이 : 84/397 proceed...
# err in 83
# 춘식이 : 85/397 proceed...
# err in 84
# 춘식이 : 86/397 proceed...
# err in 85
# 춘식이 : 87/397 proceed...
# err in 86
# 춘식이 : 88/397 proceed...
# err in 87
# 춘식이 : 89/397 proceed...
# err in 88
# 춘식이 : 90/397 proceed...
# err in 89
# 춘식이 : 91/397 proceed...
# err in 90
# 춘식이 : 92/397 proceed...
# err in 91
# 춘식이 : 93/397 proceed...
# err in 92
# 춘식이 : 94/397 proceed...
# err in 93
# 춘식이 : 95/397 proceed...
# err in 94
# 춘식이 : 96/397 proceed...
# err in 95
# 춘식이 : 97/397 proceed...
# err in 96
# 춘식이 : 98/397 proceed...
# err in 97
# 춘식이 : 99/397 proceed...
# err in 98
# 춘식이 : 100/397 proceed...
# err in 99
# 춘식이 : 101/397 proceed...
# err in 100
# 춘식이 : 102/397 proceed...
# err in 101
# 춘식이 : 103/397 proceed...
# err in 102
# 춘식이 : 104/397 proceed...
# err in 103
# 춘식이 : 105/397 proceed...
# err in 104
# 춘식이 : 106/397 proceed...
# err in 105
# 춘식이 : 107/397 proceed...
# err in 106
# 춘식이 : 108/397 proceed...
# err in 107
# 춘식이 : 109/397 proceed...
# err in 108
# 춘식이 : 110/397 proceed...
# err in 109
# 춘식이 : 111/397 proceed...
# err in 110
# 춘식이 : 112/397 proceed...
# err in 111
# 춘식이 : 113/397 proceed...
# err in 112
# 춘식이 : 114/397 proceed...
# err in 113
# 춘식이 : 115/397 proceed...
# err in 114
# 춘식이 : 116/397 proceed...
# err in 115
# 춘식이 : 117/397 proceed...
# err in 116
# 춘식이 : 118/397 proceed...
# err in 117
# 춘식이 : 119/397 proceed...
# err in 118
# 춘식이 : 120/397 proceed...
# err in 119
# 춘식이 : 121/397 proceed...
# err in 120
# 춘식이 : 122/397 proceed...
# err in 121
# 춘식이 : 123/397 proceed...
# err in 122
# 춘식이 : 124/397 proceed...
# err in 123
# 춘식이 : 125/397 proceed...
# err in 124
# 춘식이 : 126/397 proceed...
# err in 125
# 춘식이 : 127/397 proceed...
# err in 126
# 춘식이 : 128/397 proceed...
# err in 127
# 춘식이 : 129/397 proceed...
# err in 128
# 춘식이 : 130/397 proceed...
# err in 129
# 춘식이 : 131/397 proceed...
# err in 130
# 춘식이 : 132/397 proceed...
# err in 131
# 춘식이 : 133/397 proceed...
# err in 132
# 춘식이 : 134/397 proceed...
# err in 133
# 춘식이 : 135/397 proceed...
# err in 134
# 춘식이 : 136/397 proceed...
# err in 135
# 춘식이 : 137/397 proceed...
# err in 136
# 춘식이 : 138/397 proceed...
# err in 137
# 춘식이 : 139/397 proceed...
# err in 138
# 춘식이 : 140/397 proceed...
# err in 139
# 춘식이 : 141/397 proceed...
# err in 140
# 춘식이 : 142/397 proceed...
# err in 141
# 춘식이 : 143/397 proceed...
# err in 142
# 춘식이 : 144/397 proceed...
# err in 143
# 춘식이 : 145/397 proceed...
# err in 144
# 춘식이 : 146/397 proceed...
# err in 145
# 춘식이 : 147/397 proceed...
# err in 146
# 춘식이 : 148/397 proceed...
# err in 147
# 춘식이 : 149/397 proceed...
# err in 148
# 춘식이 : 150/397 proceed...
# err in 149
# 춘식이 : 151/397 proceed...
# err in 150
# 춘식이 : 152/397 proceed...
# err in 151
# 춘식이 : 153/397 proceed...
# err in 152
# 춘식이 : 154/397 proceed...
# err in 153
# 춘식이 : 155/397 proceed...
# err in 154
# 춘식이 : 156/397 proceed...
# err in 155
# 춘식이 : 157/397 proceed...
# err in 156
# 춘식이 : 158/397 proceed...
# err in 157
# 춘식이 : 159/397 proceed...
# err in 158
# 춘식이 : 160/397 proceed...
# err in 159
# 춘식이 : 161/397 proceed...
# err in 160
# 춘식이 : 162/397 proceed...
# err in 161
# 춘식이 : 163/397 proceed...
# err in 162
# 춘식이 : 164/397 proceed...
# err in 163
# 춘식이 : 165/397 proceed...
# err in 164
# 춘식이 : 166/397 proceed...
# err in 165
# 춘식이 : 167/397 proceed...
# err in 166
# 춘식이 : 168/397 proceed...
# err in 167
# 춘식이 : 169/397 proceed...
# err in 168
# 춘식이 : 170/397 proceed...
# err in 169
# 춘식이 : 171/397 proceed...
# err in 170
# 춘식이 : 172/397 proceed...
# err in 171
# 춘식이 : 173/397 proceed...
# err in 172
# 춘식이 : 174/397 proceed...
# err in 173
# 춘식이 : 175/397 proceed...
# err in 174
# 춘식이 : 176/397 proceed...
# err in 175
# 춘식이 : 177/397 proceed...
# err in 176
# 춘식이 : 178/397 proceed...
# err in 177
# 춘식이 : 179/397 proceed...
# err in 178
# 춘식이 : 180/397 proceed...
# err in 179
# 춘식이 : 181/397 proceed...
# err in 180
# 춘식이 : 182/397 proceed...
# err in 181
# 춘식이 : 183/397 proceed...
# err in 182
# 춘식이 : 184/397 proceed...
# err in 183
# 춘식이 : 185/397 proceed...
# err in 184
# 춘식이 : 186/397 proceed...
# err in 185
# 춘식이 : 187/397 proceed...
# err in 186
# 춘식이 : 188/397 proceed...
# err in 187
# 춘식이 : 189/397 proceed...
# err in 188
# 춘식이 : 190/397 proceed...
# err in 189
# 춘식이 : 191/397 proceed...
# err in 190
# 춘식이 : 192/397 proceed...
# err in 191
# 춘식이 : 193/397 proceed...
# err in 192
# 춘식이 : 194/397 proceed...
# err in 193
# 춘식이 : 195/397 proceed...
# err in 194
# 춘식이 : 196/397 proceed...
# err in 195
# 춘식이 : 197/397 proceed...
# err in 196
# 춘식이 : 198/397 proceed...
# err in 197
# 춘식이 : 199/397 proceed...
# err in 198
# 춘식이 : 200/397 proceed...
# err in 199
# 춘식이 : 201/397 proceed...
# err in 200
# 춘식이 : 202/397 proceed...
# err in 201
# 춘식이 : 203/397 proceed...
# err in 202
# 춘식이 : 204/397 proceed...
# err in 203
# 춘식이 : 205/397 proceed...
# err in 204
# 춘식이 : 206/397 proceed...
# err in 205
# 춘식이 : 207/397 proceed...
# err in 206
# 춘식이 : 208/397 proceed...
# err in 207
# 춘식이 : 209/397 proceed...
# err in 208
# 춘식이 : 210/397 proceed...
# err in 209
# 춘식이 : 211/397 proceed...
# err in 210
# 춘식이 : 212/397 proceed...
# err in 211
# 춘식이 : 213/397 proceed...
# err in 212
# 춘식이 : 214/397 proceed...
# err in 213
# 춘식이 : 215/397 proceed...
# err in 214
# 춘식이 : 216/397 proceed...
# err in 215
# 춘식이 : 217/397 proceed...
# err in 216
# 춘식이 : 218/397 proceed...
# err in 217
# 춘식이 : 219/397 proceed...
# err in 218
# 춘식이 : 220/397 proceed...
# err in 219
# 춘식이 : 221/397 proceed...
# err in 220
# 춘식이 : 222/397 proceed...
# err in 221
# 춘식이 : 223/397 proceed...
# err in 222
# 춘식이 : 224/397 proceed...
# err in 223
# 춘식이 : 225/397 proceed...
# err in 224
# 춘식이 : 226/397 proceed...
# err in 225
# 춘식이 : 227/397 proceed...
# err in 226
# 춘식이 : 228/397 proceed...
# err in 227
# 춘식이 : 229/397 proceed...
# err in 228
# 춘식이 : 230/397 proceed...
# err in 229
# 춘식이 : 231/397 proceed...
# err in 230
# 춘식이 : 232/397 proceed...
# err in 231
# 춘식이 : 233/397 proceed...
# err in 232
# 춘식이 : 234/397 proceed...
# err in 233
# 춘식이 : 235/397 proceed...
# err in 234
# 춘식이 : 236/397 proceed...
# err in 235
# 춘식이 : 237/397 proceed...
# err in 236
# 춘식이 : 238/397 proceed...
# err in 237
# 춘식이 : 239/397 proceed...
# err in 238
# 춘식이 : 240/397 proceed...
# err in 239
# 춘식이 : 241/397 proceed...
# err in 240
# 춘식이 : 242/397 proceed...
# err in 241
# 춘식이 : 243/397 proceed...
# err in 242
# 춘식이 : 244/397 proceed...
# err in 243
# 춘식이 : 245/397 proceed...
# err in 244
# 춘식이 : 246/397 proceed...
# err in 245
# 춘식이 : 247/397 proceed...
# err in 246
# 춘식이 : 248/397 proceed...
# err in 247
# 춘식이 : 249/397 proceed...
# err in 248
# 춘식이 : 250/397 proceed...
# err in 249
# 춘식이 : 251/397 proceed...
# err in 250
# 춘식이 : 252/397 proceed...
# err in 251
# 춘식이 : 253/397 proceed...
# err in 252
# 춘식이 : 254/397 proceed...
# err in 253
# 춘식이 : 255/397 proceed...
# err in 254
# 춘식이 : 256/397 proceed...
# err in 255
# 춘식이 : 257/397 proceed...
# err in 256
# 춘식이 : 258/397 proceed...
# err in 257
# 춘식이 : 259/397 proceed...
# err in 258
# 춘식이 : 260/397 proceed...
# err in 259
# 춘식이 : 261/397 proceed...
# err in 260
# 춘식이 : 262/397 proceed...
# err in 261
# 춘식이 : 263/397 proceed...
# err in 262
# 춘식이 : 264/397 proceed...
# err in 263
# 춘식이 : 265/397 proceed...
# err in 264
# 춘식이 : 266/397 proceed...
# err in 265
# 춘식이 : 267/397 proceed...
# err in 266
# 춘식이 : 268/397 proceed...
# err in 267
# 춘식이 : 269/397 proceed...
# err in 268
# 춘식이 : 270/397 proceed...
# err in 269
# 춘식이 : 271/397 proceed...
# err in 270
# 춘식이 : 272/397 proceed...
# err in 271
# 춘식이 : 273/397 proceed...
# err in 272
# 춘식이 : 274/397 proceed...
# err in 273
# 춘식이 : 275/397 proceed...
# err in 274
# 춘식이 : 276/397 proceed...
# err in 275
# 춘식이 : 277/397 proceed...
# err in 276
# 춘식이 : 278/397 proceed...
# err in 277
# 춘식이 : 279/397 proceed...
# err in 278
# 춘식이 : 280/397 proceed...
# err in 279
# 춘식이 : 281/397 proceed...
# err in 280
# 춘식이 : 282/397 proceed...
# err in 281
# 춘식이 : 283/397 proceed...
# err in 282
# 춘식이 : 284/397 proceed...
# err in 283
# 춘식이 : 285/397 proceed...
# err in 284
# 춘식이 : 286/397 proceed...
# err in 285
# 춘식이 : 287/397 proceed...
# err in 286
# 춘식이 : 288/397 proceed...
# err in 287
# 춘식이 : 289/397 proceed...
# err in 288
# 춘식이 : 290/397 proceed...
# err in 289
# 춘식이 : 291/397 proceed...
# err in 290
# 춘식이 : 292/397 proceed...
# err in 291
# 춘식이 : 293/397 proceed...
# err in 292
# 춘식이 : 294/397 proceed...
# err in 293
# 춘식이 : 295/397 proceed...
# err in 294
# 춘식이 : 296/397 proceed...
# err in 295
# 춘식이 : 297/397 proceed...
# err in 296
# 춘식이 : 298/397 proceed...
# err in 297
# 춘식이 : 299/397 proceed...
# err in 298
# 춘식이 : 300/397 proceed...
# err in 299
# 춘식이 : 301/397 proceed...
# err in 300
# 춘식이 : 302/397 proceed...
# err in 301
# 춘식이 : 303/397 proceed...
# err in 302
# 춘식이 : 304/397 proceed...
# err in 303
# 춘식이 : 305/397 proceed...
# err in 304
# 춘식이 : 306/397 proceed...
# err in 305
# 춘식이 : 307/397 proceed...
# err in 306
# 춘식이 : 308/397 proceed...
# err in 307
# 춘식이 : 309/397 proceed...
# err in 308
# 춘식이 : 310/397 proceed...
# err in 309
# 춘식이 : 311/397 proceed...
# err in 310
# 춘식이 : 312/397 proceed...
# err in 311
# 춘식이 : 313/397 proceed...
# err in 312
# 춘식이 : 314/397 proceed...
# err in 313
# 춘식이 : 315/397 proceed...
# err in 314
# 춘식이 : 316/397 proceed...
# err in 315
# 춘식이 : 317/397 proceed...
# err in 316
# 춘식이 : 318/397 proceed...
# err in 317
# 춘식이 : 319/397 proceed...
# err in 318
# 춘식이 : 320/397 proceed...
# err in 319
# 춘식이 : 321/397 proceed...
# err in 320
# 춘식이 : 322/397 proceed...
# err in 321
# 춘식이 : 323/397 proceed...
# err in 322
# 춘식이 : 324/397 proceed...
# err in 323
# 춘식이 : 325/397 proceed...
# err in 324
# 춘식이 : 326/397 proceed...
# err in 325
# 춘식이 : 327/397 proceed...
# err in 326
# 춘식이 : 328/397 proceed...
# err in 327
# 춘식이 : 329/397 proceed...
# err in 328
# 춘식이 : 330/397 proceed...
# err in 329
# 춘식이 : 331/397 proceed...
# err in 330
# 춘식이 : 332/397 proceed...
# err in 331
# 춘식이 : 333/397 proceed...
# err in 332
# 춘식이 : 334/397 proceed...
# err in 333
# 춘식이 : 335/397 proceed...
# err in 334
# 춘식이 : 336/397 proceed...
# err in 335
# 춘식이 : 337/397 proceed...
# err in 336
# 춘식이 : 338/397 proceed...
# err in 337
# 춘식이 : 339/397 proceed...
# err in 338
# 춘식이 : 340/397 proceed...
# err in 339
# 춘식이 : 341/397 proceed...
# err in 340
# 춘식이 : 342/397 proceed...
# err in 341
# 춘식이 : 343/397 proceed...
# err in 342
# 춘식이 : 344/397 proceed...
# err in 343
# 춘식이 : 345/397 proceed...
# err in 344
# 춘식이 : 346/397 proceed...
# err in 345
# 춘식이 : 347/397 proceed...
# err in 346
# 춘식이 : 348/397 proceed...
# err in 347
# 춘식이 : 349/397 proceed...
# err in 348
# 춘식이 : 350/397 proceed...
# err in 349
# 춘식이 : 351/397 proceed...
# err in 350
# 춘식이 : 352/397 proceed...
# err in 351
# 춘식이 : 353/397 proceed...
# err in 352
# 춘식이 : 354/397 proceed...
# err in 353
# 춘식이 : 355/397 proceed...
# err in 354
# 춘식이 : 356/397 proceed...
# err in 355
# 춘식이 : 357/397 proceed...
# err in 356
# 춘식이 : 358/397 proceed...
# err in 357
# 춘식이 : 359/397 proceed...
# err in 358
# 춘식이 : 360/397 proceed...
# err in 359
# 춘식이 : 361/397 proceed...
# err in 360
# 춘식이 : 362/397 proceed...
# err in 361
# 춘식이 : 363/397 proceed...
# err in 362
# 춘식이 : 364/397 proceed...
# err in 363
# 춘식이 : 365/397 proceed...
# err in 364
# 춘식이 : 366/397 proceed...
# err in 365
# 춘식이 : 367/397 proceed...
# err in 366
# 춘식이 : 368/397 proceed...
# err in 367
# 춘식이 : 369/397 proceed...
# err in 368
# 춘식이 : 370/397 proceed...
# err in 369
# 춘식이 : 371/397 proceed...
# err in 370
# 춘식이 : 372/397 proceed...
# err in 371
# 춘식이 : 373/397 proceed...
# err in 372
# 춘식이 : 374/397 proceed...
# err in 373
# 춘식이 : 375/397 proceed...
# err in 374
# 춘식이 : 376/397 proceed...
# err in 375
# 춘식이 : 377/397 proceed...
# err in 376
# 춘식이 : 378/397 proceed...
# err in 377
# 춘식이 : 379/397 proceed...
# err in 378
# 춘식이 : 380/397 proceed...
# err in 379
# 춘식이 : 381/397 proceed...
# err in 380
# 춘식이 : 382/397 proceed...
# err in 381
# 춘식이 : 383/397 proceed...
# err in 382
# 춘식이 : 384/397 proceed...
# err in 383
# 춘식이 : 385/397 proceed...
# err in 384
# 춘식이 : 386/397 proceed...
# err in 385
# 춘식이 : 387/397 proceed...
# err in 386
# 춘식이 : 388/397 proceed...
# err in 387
# 춘식이 : 389/397 proceed...
# err in 388
# 춘식이 : 390/397 proceed...
# err in 389
# 춘식이 : 391/397 proceed...
# err in 390
# 춘식이 : 392/397 proceed...
# err in 391
# 춘식이 : 393/397 proceed...
# err in 392
# 춘식이 : 394/397 proceed...
# err in 393
# 춘식이 : 395/397 proceed...
# err in 394
# 춘식이 : 396/397 proceed...
# err in 395
# 춘식이 : 397/397 proceed...
# err in 396
# /var/folders/w8/dhsjkhfn205_vq9r6d5nxq1w0000gn/T/ipykernel_1946/2071511420.py:94: SyntaxWarning: invalid escape sequence '\{'
#   save_path = f'C:\ccestcrawl\{query}'
# /var/folders/w8/dhsjkhfn205_vq9r6d5nxq1w0000gn/T/ipykernel_1946/2071511420.py:94: SyntaxWarning: invalid escape sequence '\c'
#   save_path = f'C:\ccestcrawl\{query}'
# /var/folders/w8/dhsjkhfn205_vq9r6d5nxq1w0000gn/T/ipykernel_1946/2071511420.py:102: SyntaxWarning: invalid escape sequence '\{'
#   urllib.request.urlretrieve(src,  f"{save_path}\{query}_{idx}.png")
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Cell In[2], line 93
#      91         print(f'err in {idx}')
#      92         pass
# ---> 93 driver.close()
#      94 save_path = f'C:\ccestcrawl\{query}'
#      95 import os
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/selenium/webdriver/remote/webdriver.py:459, in WebDriver.close(self)
#     451 def close(self) -> None:
#     452     """Closes the current window.
#     453
#     454     :Usage:
#    (...)
#     457             driver.close()
#     458     """
# --> 459     self.execute(Command.CLOSE)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/selenium/webdriver/remote/webdriver.py:348, in WebDriver.execute(self, driver_command, params)
#     346 response = self.command_executor.execute(driver_command, params)
#     347 if response:
# --> 348     self.error_handler.check_response(response)
#     349     response["value"] = self._unwrap_value(response.get("value", None))
#     350     return response
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/selenium/webdriver/remote/errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=120.0.6099.71)
# Stacktrace:
# 0   chromedriver                        0x0000000106eb8c48 chromedriver + 4852808
# 1   chromedriver                        0x0000000106eb01b3 chromedriver + 4817331
# 2   chromedriver                        0x0000000106a7c7bd chromedriver + 411581
# 3   chromedriver                        0x0000000106a502f8 chromedriver + 230136
# 4   chromedriver                        0x0000000106afe41f chromedriver + 943135
# 5   chromedriver                        0x0000000106b04c64 chromedriver + 969828
# 6   chromedriver                        0x0000000106af6bc8 chromedriver + 912328
# 7   chromedriver                        0x0000000106abe103 chromedriver + 680195
# 8   chromedriver                        0x0000000106abf71e chromedriver + 685854
# 9   chromedriver                        0x0000000106e78792 chromedriver + 4589458
# 10  chromedriver                        0x0000000106e7d99c chromedriver + 4610460
# 11  chromedriver                        0x0000000106e5dcb1 chromedriver + 4480177
# 12  chromedriver                        0x0000000106e7e716 chromedriver + 4613910
# 13  chromedriver                        0x0000000106e4f23c chromedriver + 4420156
# 14  chromedriver                        0x0000000106e9e798 chromedriver + 4745112
# 15  chromedriver                        0x0000000106e9e94e chromedriver + 4745550
# 16  chromedriver                        0x0000000106eafdf3 chromedriver + 4816371
# 17  libsystem_pthread.dylib             0x00007ff8121e11d3 _pthread_start + 125
# 18  libsystem_pthread.dylib             0x00007ff8121dcbd3 thread_start + 15
